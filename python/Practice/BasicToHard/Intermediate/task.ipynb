# %%
#TASK 1: Variables, Print, Input (Intermediate)
#Practice 1: Student Report Generato
#Task
#Take input: name, id, marks in 3 subjects
#Calculate:
#total
#average
#grade (A/B/C/F)
#Print a formatted report
#Concepts used
#Variables
#Input
#Print formatting (f-string)

name = input("Enter student name: ")
std_id = input("Enter student ID: ")
marks1 = float(input("Enter marks in subject 1: "))
marks2 = float(input("enter marks in subject 2: "))
marks3 = float(input("Eneter marks in subject 3: "))
total = marks1 + marks2 + marks3
avr = total/3
print("Total marks in 3 subjects: ", total)
print("Average marks: ", avr)
if avr >= 80:
    grade = 'A'
elif avr >= 60:
    grade = 'B'
elif avr >= 40:
    grade = 'C'
else:
    grade = 'F'
print(f"student name: {name}")
print(f"Student ID: {std_id}")
print(f"Total Marks: {total}")
print(f"Average Marks: {avr}")
print(f"Grade: {grade}")
# Out:
# Total marks in 3 subjects:  102.0
# Average marks:  34.0
# student name: sara
# Student ID: 2002
# Total Marks: 102.0
# Average Marks: 34.0
# Grade: F

# %%
#Practice 2: Currency Converter
#Task
#Take amount in BDT
#Convert to USD, EUR (fixed rate)
#Print results with 2 decimal places
#Bonus
#Ask user which currency they want

BD = float(input("Enter amount in BDT: "))
USD_rate = 0.012
EUR_rate = 0.011
USD_rate = BD * USD_rate
EUR_rate = BD * EUR_rate
print(f"Amount in USD: {USD_rate:.2f}")
print(f"Amount in EUR: {EUR_rate:.2f}")
# Out:
# Amount in USD: 24.00
# Amount in EUR: 22.00

# %%
def group_anagrams(words):
    anagram_dict = {}

    for word in words:
        key = "".join(sorted(word))

        if key not in anagram_dict:
            anagram_dict[key] = []

        anagram_dict[key].append(word)

    return list(anagram_dict.values())


words = ["eat","tea","tan","ate","nat","bat"]
print(group_anagrams(words))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
def find_missing(nums):
    n = len(nums) + 1

    expected_sum = n * (n + 1) // 2
    actual_sum = sum(nums)

    return expected_sum - actual_sum


nums = [1,2,3,5,6]
print(find_missing(nums))
# Out:
# 4

# %%
def longest_unique_substring(s):
    seen = set()
    left = 0
    max_length = 0

    for right in range(len(s)):
        while s[right] in seen:
            seen.remove(s[left])
            left += 1

        seen.add(s[right])
        max_length = max(max_length, right - left + 1)

    return max_length


print(longest_unique_substring("abcabcbb"))
# Out:
# 3
